","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"8c1ad9ab-5686-4d0a-a1cf-3cdad578e02e","type":"Line"},"selection_glyph":null,"view":{"id":"3dbad3c2-565d-4ac4-ae67-b633263cb15a","type":"CDSView"}},"id":"558b7f0a-cf24-4cee-961c-a0c31660a655","type":"GlyphRenderer"},{"attributes":{"overlay":{"id":"60287ecc-c234-4754-a0f4-991e5faafdc1","type":"BoxAnnotation"}},"id":"749b04b2-59be-48df-965a-4ad94b09bc30","type":"BoxZoomTool"},{"attributes":{},"id":"3df1f19b-359c-492b-8788-a208d17593d9","type":"ResetTool"},{"attributes":{"formatter":{"id":"ce03d3f6-732a-4610-8ac2-2254273364f8","type":"BasicTickFormatter"},"plot":{"id":"efe70398-26c1-481e-b6b9-886d6c4bb499","subtype":"Figure","type":"Plot"},"ticker":{"id":"b10f5742-ac9a-4183-b799-0142675317d6","type":"BasicTicker"}},"id":"1f6d218f-f4db-41b3-979f-484c80ece3c3","type":"LinearAxis"},{"attributes":{},"id":"0e059ab0-0aea-4462-a333-ff2797b27d5b","type":"SaveTool"},{"attributes":{"callback":null},"id":"fb37e211-60da-4eca-a33e-1971b66cb0c4","type":"DataRange1d"},{"attributes":{},"id":"da9e00c5-3807-431c-ab53-a7cfaec009cf","type":"BasicTickFormatter"},{"attributes":{"source":{"id":"9d018b44-ccca-45a4-8f04-6c8d093dae93","type":"ColumnDataSource"}},"id":"3dbad3c2-565d-4ac4-ae67-b633263cb15a","type":"CDSView"},{"attributes":{"plot":{"id":"efe70398-26c1-481e-b6b9-886d6c4bb49 ...

# %%
# create a Figure object
p = figure(width=300, height=300, tools="pan,reset,save")

# add a Circle renderer to this figure
p.circle([1, 2.5, 3, 4], [2, 3, 1, 1.5], radius=1, alpha=0.9)

# specify how to output the plot(s)
output_file("foo.html")

# display the figure
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="24e5cb1b-8dd4-4978-b9a0-6bff27a7f245"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("24e5cb1b-8dd4-4978-b9a0-6bff27a7f245");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("24e5cb1b-8dd4-4978-b9a0-6bff27a7f245");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '24e5cb1b-8dd4-4978-b9a0-6bff27a7f245' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"6360dcdc-6e65-4809-8a13-8fc81ee8fbe4":{"roots":{"references":[{"attributes":{},"id":"bb148139-8b52-4175-bfd6-4fbe1dc109bb","type":"BasicTicker"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"8c226c53-00df-44bb-8181-797a04fa8a6c","type":"PanTool"},{"id":"69ad1685-f1d8-45df-9001-3c64c30cc054","type":"ResetTool"},{"id":"4423d39e-0386-4982-b76b-08b4776fefcc","type":"SaveTool"}]},"id":"f7e7a877-62af-471d-ab5b-b8d5aabfe6ac","type":"Toolbar"},{"attributes":{"callback":null},"id":"69182320-fa34-475d-ab1d-5c7fff4fbc34","type":"DataRange1d"},{"attributes":{},"id":"8c226c53-00df-44bb-8181-797a04fa8a6c","type":"PanTool"},{"attributes":{},"id":"431f9d30-7fe8-4825-b090-bc006137ac42","type":"LinearScale"},{"attributes":{"data_source":{"id":"d51579ed-9815-40e6-8ab3-59e58b7caa21","type":"ColumnDataSource"},"glyph":{"id":"0020729c-1dfc-4455-8342-de3305871020","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":
"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"a34b2290-6e6b-4d1d-9243-fed019d6e223","type":"SquareCross"},"selection_glyph":null,"view":{"id":"62f859c1-150f-42ce-aa85-0df84aa3257c","type":"CDSView"}},"id":"16220f32-95c1-4542-a9ab-aed77c1625ea","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"14a20a3e-94ad-4cec-8f68-c8bd48c67cfd","type":"DataRange1d"},{"attributes":{"plot":{"id":"6eb042d1-50b8-421f-bb8a-a47e089eefc2","subtype":"Figure","type":"Plot"},"ticker":{"id":"df128c5a-0a7d-4994-9367-4b61d473b52c","type":"BasicTicker"}},"id":"2a53fc20-1045-4f26-8caf-cda02064801c","type":"Grid"},{"attributes":{"overlay":{"id":"35367aa4-f9d3-4d1a-8043-028d4d9fd59d","type":"BoxAnnotation"}},"id":"388ad0a3-98ab-4b90-8395-6843b75ff55e","type":"BoxZoomTool"},{"attributes":{},"id":"5e45b14f-0df9-4597-a354-7edfd026b636","type":"SaveTool"},{"attributes":{},"id":"6a154b15-7894-4ad0-ba03-813b527b6350","type":"ResetTool"},{"attributes":{"formatter":{"id":"3b5fe3d9-8380-4378-98b8-7f01f6e41bf7","type":"BasicTickFormatter"},"plot":{"id":"6eb042d1-50b8-421f-bb8a-a47e089eefc2","subtype":"Figure","type":"Plot"},"ticker":{"id":"df128c5a-0a7d-4994-9367-4b61 ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-d64e645d93e9> in <module>()
#       8 # Update the plot title in the earlier cell
#       9 p.title.text = "New Title"
# ---> 10 push_notebook(handle=handle)
#
# NameError: name 'push_notebook' is not defined

# %%
AAPL = pd.read_csv(
        "http://ichart.yahoo.com/table.csv?s=AAPL&a=0&b=1&c=2000&d=0&e=1&f=2010",
        parse_dates=['Date']
    )

#output_file("datetime.html")

# create a new plot with a datetime axis type
p = figure(width=800, height=250, x_axis_type="datetime")

p.line(AAPL['Date'], AAPL['Close'], color='navy', alpha=0.5)

show(p)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\Miniconda3\envs\ttapy\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1317                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1318                           encode_chunked=req.has_header('Transfer-encoding'))
#    1319             except OSError as err: # timeout error
#
# ~\Miniconda3\envs\ttapy\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#
# ~\Miniconda3\envs\ttapy\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#
# ~\Miniconda3\envs\ttapy\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1233             raise CannotSendHeader()
# -> 1234         self._send_output(message_body, encode_chunked=encode_chunked)
#    1235
#
# ~\Miniconda3\envs\ttapy\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# ~\Miniconda3\envs\ttapy\lib\http\client.py in send(self, data)
#     963             if self.auto_open:
# --> 964                 self.connect()
#     965             else:
#
# ~\Miniconda3\envs\ttapy\lib\http\client.py in connect(self)
#     935         self.sock = self._create_connection(
# --> 936             (self.host,self.port), self.timeout, self.source_address)
#     937         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# ~\Miniconda3\envs\ttapy\lib\socket.py in create_connection(address, timeout, source_address)
#     703     err = None
# --> 704     for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     705         af, socktype, proto, canonname, sa = res
#
# ~\Miniconda3\envs\ttapy\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     742     addrlist = []
# --> 743     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     744         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11004] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# <ipython-input-25-863c284305cb> in <module>()
#       1 AAPL = pd.read_csv(
#       2         "http://ichart.yahoo.com/table.csv?s=AAPL&a=0&b=1&c=2000&d=0&e=1&f=2010",
# ----> 3         parse_dates=['Date']
#       4     )
#       5
#
# ~\Miniconda3\envs\ttapy\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     653                     skip_blank_lines=skip_blank_lines)
#     654
# --> 655         return _read(filepath_or_buffer, kwds)
#     656
#     657     parser_f.__name__ = name
#
# ~\Miniconda3\envs\ttapy\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     390     compression = _infer_compression(filepath_or_buffer, compression)
#     391     filepath_or_buffer, _, compression = get_filepath_or_buffer(
# --> 392         filepath_or_buffer, encoding, compression)
#     393     kwds['compression'] = compression
#     394
#
# ~\Miniconda3\envs\ttapy\lib\site-packages\pandas\io\common.py in get_filepath_or_buffer(filepath_or_buffer, encoding, compression)
#     184     if _is_url(filepath_or_buffer):
#     185         url = str(filepath_or_buffer)
# --> 186         req = _urlopen(url)
#     187         content_encoding = req.headers.get('Content-Encoding', None)
#     188         if content_encoding == 'gzip':
#
# ~\Miniconda3\envs\ttapy\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# ~\Miniconda3\envs\ttapy\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     524             req = meth(req)
#     525
# --> 526         response = self._open(req, data)
#     527
#     528         # post-process response
#
# ~\Miniconda3\envs\ttapy\lib\urllib\request.py in _open(self, req, data)
#     542         protocol = req.type
#     543         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 544                                   '_open', req)
#     545         if result:
#     546             return result
#
# ~\Miniconda3\envs\ttapy\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# ~\Miniconda3\envs\ttapy\lib\urllib\request.py in http_open(self, req)
#    1344
#    1345     def http_open(self, req):
# -> 1346         return self.do_open(http.client.HTTPConnection, req)
#    1347
#    1348     http_request = AbstractHTTPHandler.do_request_
#
# ~\Miniconda3\envs\ttapy\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1318                           encode_chunked=req.has_header('Transfer-encoding'))
#    1319             except OSError as err: # timeout error
# -> 1320                 raise URLError(err)
#    1321             r = h.getresponse()
#    1322         except:
#
# URLError: <urlopen error [Errno 11004] getaddrinfo failed>
